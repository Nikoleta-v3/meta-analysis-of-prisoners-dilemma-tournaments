# %%
import pandas as pd

# %%
noise_dfs = [pd.read_csv('../data/noise_v3.csv', index_col=0),
             pd.read_csv('../data/noise_v4.csv', index_col=0)]
# Out:
# /home/nightwing/anaconda3/envs/axlml/lib/python3.5/site-packages/numpy/lib/arraysetops.py:472: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
noise_dfs[0].describe()
# Out:
#                Rank  Median_score  Cooperation_rating          Wins  \
# count  1.098915e+06  1.098915e+06        1.098915e+06  1.098915e+06
# mean   6.063600e+01  2.248986e+00        5.007192e-01  5.747850e+01
# std    4.443462e+01  3.236658e-01        1.578931e-01  3.665046e+01
# min    0.000000e+00  1.869048e-01        0.000000e+00  0.000000e+00
# 25%    2.300000e+01  2.118306e+00        4.298007e-01  2.800000e+01
# 50%    5.200000e+01  2.234758e+00        4.994116e-01  5.200000e+01
# 75%    9.100000e+01  2.327306e+00        5.693373e-01  8.000000e+01
# max    1.940000e+02  4.860656e+00        1.000000e+00  1.870000e+02
#
#        Initial_C_rate       CC_rate       CD_rate       DC_rate       DD_rate  \
# count    1.098915e+06  1.098915e+06  1.098915e+06  1.098915e+06  1.098915e+06
# mean     4.979083e-01  2.531210e-01  2.475983e-01  2.475983e-01  2.516825e-01
# std      2.814308e-01  9.449125e-02  9.493757e-02  9.444976e-02  1.018308e-01
# ...

# %%
noise_dfs[0].iloc[0]
# Out:
# Rank                                  0
# Name                  Cooperator Hunter
# Median_score                    3.34724
# Cooperation_rating             0.152237
# Wins                                 96
# Initial_C_rate                   0.1435
# CC_rate                        0.098972
# CD_rate                       0.0532649
# DC_rate                        0.550556
# DD_rate                        0.297207
# CC_to_C_rate                   0.157721
# CD_to_C_rate                   0.152564
# DC_to_C_rate                   0.152024
# DD_to_C_rate                   0.150916
# noise                          0.849486
# turns                               134
# repetitions                          40
# size                                101
# seed                                  0
# Name: 0, dtype: object

# %%
noise_dfs[1].iloc[0]
# Out:
# Rank                           0
# Name                  Cooperator
# Median_score             3.29792
# Cooperation_rating      0.162643
# Wins                         209
# Initial_C_rate          0.167004
# CC_rate                 0.104254
# CD_rate                0.0583891
# DC_rate                 0.536788
# DD_rate                 0.300569
# CC_to_C_rate            0.160697
# CD_to_C_rate             0.16282
# DC_to_C_rate            0.162474
# DD_to_C_rate            0.163186
# noise                   0.837661
# turns                         92
# repetitions                   59
# size                         219
# seed                           0
# Name: 0, dtype: object

# %%
noise_dfs[1].describe()
# Out:
#                Rank  Median_score  Cooperation_rating          Wins  \
# count  93691.000000  93691.000000        93691.000000  93691.000000
# mean      76.403625      2.249275            0.501961     72.462125
# std       52.909065      0.314637            0.154010     42.914164
# min        0.000000      0.573529            0.000485      0.000000
# 25%       31.000000      2.118232            0.436460     37.750000
# 50%       68.000000      2.233121            0.499628     68.000000
# 75%      116.000000      2.333113            0.568854    101.000000
# max      218.000000      4.250363            0.996283    210.000000
#
#        Initial_C_rate       CC_rate       CD_rate       DC_rate       DD_rate  \
# count    93691.000000  93691.000000  93691.000000  93691.000000  93691.000000
# mean         0.496467      0.256581      0.245380      0.245380      0.252659
# std          0.281667      0.096044      0.093147      0.091896      0.102751
# ...

# %%
df = pd.concat(noise_dfs)

# %%
df.head()
# Out:
#    Rank               Name  Median_score  Cooperation_rating  Wins  \
# 0     0  Cooperator Hunter      3.347239            0.152237  96.0
# 1     1                $e$      3.307425            0.174586  94.0
# 2     2  Hesitant QLearner      3.270746            0.186011  93.0
# 3     3   Opposite Grudger      3.269142            0.170526  94.0
# 4     4     Risky QLearner      3.268843            0.187037  93.0
#
#    Initial_C_rate   CC_rate   CD_rate   DC_rate   DD_rate  CC_to_C_rate  \
# 0         0.14350  0.098972  0.053265  0.550556  0.297207      0.157721
# 1         0.15025  0.116172  0.058414  0.533892  0.291522      0.225727
# 2         0.18450  0.119065  0.066946  0.523808  0.290181      0.184686
# 3         0.85475  0.100909  0.069618  0.533244  0.296229      0.148978
# 4         0.19350  0.119571  0.067466  0.523174  0.289789      0.184768
#
#    CD_to_C_rate  DC_to_C_rate  DD_to_C_rate     noise  turns  repetitions  \
# ...

# %%
df[df.duplicated()]
# Out:
#         Rank                                               Name  Median_score  \
# 1818       0                                 CollectiveStrategy      2.271452
# 1819       1                                           Defector      2.271290
# 1820       2                        NMWE Memory One: 30 players      2.270161
# 1821       3                                   Hard Tit For Tat      2.269301
# 1822       4                              Revised Downing: True      2.267419
# 1823       5                 Meta Winner Stochastic: 47 players      2.267312
# 1824       6                           Meta Winner: 173 players      2.267151
# 1825       7                                     Level Punisher      2.267043
# 1826       8                                           Adaptive      2.266935
# 1827       9                                            Grudger      2.266882
# 1828      10                          DoubleCrosser: ('D', 'D')      2.266452
# ...
