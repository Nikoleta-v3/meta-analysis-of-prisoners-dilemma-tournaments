# %%
import pandas as pd
import read_in

from tqdm import tqdm

# %%
import glob

# %%
df = pd.read_csv('../data/std-data/0.csv')

# %%
parameters_df = pd.read_csv('../data/parameters_0-2000.csv')
parameters_df.tail()
# Out:
#         noise              player_0      player_1                player_10  \
# 370  0.992490  Adaptive Pavlov 2011  Resurrection  Evolved FSM 16 Noise 05
# 371  0.830428  Adaptive Pavlov 2011  Resurrection  Evolved FSM 16 Noise 05
# 372  0.414439  Adaptive Pavlov 2011  Resurrection  Evolved FSM 16 Noise 05
# 373  0.981225  Adaptive Pavlov 2011  Resurrection  Evolved FSM 16 Noise 05
# 374  0.882287  Adaptive Pavlov 2011  Resurrection  Evolved FSM 16 Noise 05
#
#     player_100   player_101                     player_102     player_103  \
# 370   Forgiver  Cycler CCCD  ZD-Extort-2 v2: 0.125, 0.5, 1  Cycler CCCCCD
# 371   Forgiver  Cycler CCCD  ZD-Extort-2 v2: 0.125, 0.5, 1  Cycler CCCCCD
# 372   Forgiver  Cycler CCCD  ZD-Extort-2 v2: 0.125, 0.5, 1  Cycler CCCCCD
# 373   Forgiver  Cycler CCCD  ZD-Extort-2 v2: 0.125, 0.5, 1  Cycler CCCCCD
# 374   Forgiver  Cycler CCCD  ZD-Extort-2 v2: 0.125, 0.5, 1  Cycler CCCCCD
#
#     player_104  player_105  ...      player_95       player_96  \
# ...

# %%
list_frames = []
for i in tqdm(range(1000, 20000)):
    try:
        df = pd.read_csv('../data/std-data/{}.csv'.format(i))
        df['seed'] = i
        list_frames.append(df)
    except FileNotFoundError:
        pass #print('frame {} not here'.format(i))
data_frame = pd.concat(list_frames, ignore_index=True)
# Out:
# 100%|██████████| 19000/19000 [00:30<00:00, 630.75it/s]

# %%
data_frame.head()
# Out:
#    Rank               Name  Median_score  Cooperation_rating  Wins  \
# 0     0  PSO Gambler 2_2_2      2.896182            0.728402  23.0
# 1     1     Evolved FSM 16      2.892621            0.750742  28.0
# 2     2      Evolved ANN 5      2.889575            0.730278  24.0
# 3     3      Evolved HMM 5      2.883312            0.768560  22.0
# 4     4        Evolved ANN      2.881338            0.741578  24.0
#
#    Initial_C_rate   CC_rate   CD_rate   DC_rate   DD_rate  CC_to_C_rate  \
# 0             1.0  0.668688  0.059714  0.154109  0.117490      0.901362
# 1             1.0  0.673816  0.076926  0.155140  0.094118      0.856188
# 2             1.0  0.711186  0.019091  0.121479  0.148243      0.961437
# 3             1.0  0.727945  0.040616  0.116892  0.114548      0.996864
# 4             1.0  0.721841  0.019737  0.114488  0.143935      0.986385
#
#    CD_to_C_rate  DC_to_C_rate  DD_to_C_rate  seed
# 0      0.499978      0.550399      0.398122  1000
# ...

# %%
data_frame['seed'].unique().size
# Out:
# 11639

# %%
data_frame[(data_frame['seed']==0) & (data_frame['Rank']==0)].head()
# Out:
#    Rank                  Name  Median_score  Cooperation_rating  Wins  \
# 0     0  EvolvedLookerUp2_2_2      2.969925            0.704614  28.0
#
#    Initial_C_rate   CC_rate  CD_rate   DC_rate   DD_rate  CC_to_C_rate  \
# 0             1.0  0.639084  0.06553  0.189481  0.105905      0.835714
#
#    CD_to_C_rate  DC_to_C_rate  DD_to_C_rate  seed
# 0      0.480962      0.567606      0.800237     0

# %%
df.head()
# Out:
#    Rank                     Name  Median_score  Cooperation_rating  Wins  \
# 0     0     EvolvedLookerUp2_2_2      2.965253            0.710911  29.0
# 1     1        PSO Gambler 1_1_1      2.869293            0.688387  23.0
# 2     2  Evolved FSM 16 Noise 05      2.868990            0.701677  21.0
# 3     3         PSO Gambler Mem1      2.847778            0.710640  22.0
# 4     4             Fool Me Once      2.845657            0.639123  25.0
#
#    Initial_C_rate   CC_rate   CD_rate   DC_rate   DD_rate  CC_to_C_rate  \
# 0             1.0  0.644993  0.065918  0.185059  0.104031      0.841307
# 1             1.0  0.653223  0.035164  0.149152  0.162461      1.000000
# 2             1.0  0.678511  0.023167  0.134050  0.164273      0.984409
# 3             1.0  0.666465  0.044175  0.140479  0.148881      1.000000
# 4             1.0  0.629363  0.009759  0.148613  0.212264      1.000000
#
#    CD_to_C_rate  DC_to_C_rate  DD_to_C_rate
# 0      0.481828      0.563901      0.800173
# ...

# %%
df = pd.read_csv('../data/std-data/1.csv')

# %%
data = pd.read_csv('../data/std_df.csv')

# %%
data[(data['seed']==0) & (data['Rank']==0)].head()
# Out:
#      Unnamed: 0  Rank                  Name  Median_score  Cooperation_rating  \
# 0             0     0  EvolvedLookerUp2_2_2      2.969925            0.704614
# 101         101     0  EvolvedLookerUp2_2_2      2.969925            0.704614
# 202         202     0  EvolvedLookerUp2_2_2      2.969925            0.704614
# 303         303     0  EvolvedLookerUp2_2_2      2.969925            0.704614
# 404         404     0  EvolvedLookerUp2_2_2      2.969925            0.704614
#
#      Wins  Initial_C_rate   CC_rate  CD_rate   DC_rate   DD_rate  \
# 0    28.0             1.0  0.639084  0.06553  0.189481  0.105905
# 101  28.0             1.0  0.639084  0.06553  0.189481  0.105905
# 202  28.0             1.0  0.639084  0.06553  0.189481  0.105905
# 303  28.0             1.0  0.639084  0.06553  0.189481  0.105905
# 404  28.0             1.0  0.639084  0.06553  0.189481  0.105905
#
#      CC_to_C_rate  CD_to_C_rate  DC_to_C_rate  DD_to_C_rate  turns  \
# ...

# %%
# %time parameters_df = read_in.parameters_data_frame('../data/')
# Out:
# CPU times: user 928 ms, sys: 96 ms, total: 1.02 s
# Wall time: 1.06 s

# %%
parameters_df = parameters_df.drop_duplicates('seed')

# %%
# %time df = read_in.reading_in_data(parameters_df, '../data/')
# Out:
# CPU times: user 4min 14s, sys: 10.2 s, total: 4min 24s
# Wall time: 4min 41s

# %%
df.to_csv('../data/main.csv')

# %%
df['seed'].unique().size
# Out:
# 12287
