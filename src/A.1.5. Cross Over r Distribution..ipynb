# %% [markdown]
# A.1.5. Cross Over r Distribution.
# ---------

# %%
import pandas as pd
import tools
import numpy as np

# %matplotlib inline

# %%
import matplotlib

font = {'weight': 'bold',
        'size'   : 50}
matplotlib.rc('font', **font)

# %% [markdown]
# **$r-$ distributions of each type ploted together.**

# %%
st = pd.read_csv('data/standar_tournaments.csv')
ns = pd.read_csv('data/noise_tournaments.csv')
prb = pd.read_csv('data/probend_tournaments.csv')
ns_prb = pd.read_csv('data/noisy probend_tournaments.csv')

# %% [markdown]
# **max**

# %%
tools.r_distribution_mult_types(x1 = st['winner coop'], x2 = ns['winner coop'], 
                                x3 = prb['winner coop'], x4 = ns_prb['winner coop'],
                                y1 = st['max coop'], y2 = ns['max coop'], 
                                y3 = prb['max coop'], y4 = ns_prb['max coop'],
                                title='',
                                filename='/home/nightwing/rsc/Annual-Report/img/max.pdf')
# Out:
# /home/nightwing/anaconda3/envs/axlml/lib/python3.5/site-packages/matplotlib/cbook.py:136: MatplotlibDeprecationWarning: The set_color_cycle attribute was deprecated in version 1.5. Use set_prop_cycle instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# **min**

# %%
tools.r_distribution_mult_types(x1 = st['winner coop'], x2 = ns['winner coop'], 
                                x3 = prb['winner coop'], x4 = ns_prb['winner coop'],
                                y1 = st['min coop'], y2 = ns['min coop'], 
                                y3 = prb['min coop'], y4 = ns_prb['min coop'],
                                title='',
                                filename='/home/nightwing/rsc/Annual-Report/img/min.pdf')
# Out:
# /home/nightwing/anaconda3/envs/axlml/lib/python3.5/site-packages/matplotlib/cbook.py:136: MatplotlibDeprecationWarning: The set_color_cycle attribute was deprecated in version 1.5. Use set_prop_cycle instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# **mean**

# %%
tools.r_distribution_mult_types(x1 = st['winner coop'], x2 = ns['winner coop'], 
                                x3 = prb['winner coop'], x4 = ns_prb['winner coop'],
                                y1 = st['mean coop'], y2 = ns['mean coop'], 
                                y3 = prb['mean coop'], y4 = ns_prb['mean coop'],
                                title='', 
                                   filename='/home/nightwing/rsc/Annual-Report/img/mean.pdf')
# Out:
# /home/nightwing/anaconda3/envs/axlml/lib/python3.5/site-packages/matplotlib/cbook.py:136: MatplotlibDeprecationWarning: The set_color_cycle attribute was deprecated in version 1.5. Use set_prop_cycle instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# **median**

# %%
tools.r_distribution_mult_types(x1 = st['winner coop'], x2 = ns['winner coop'], 
                                x3 = prb['winner coop'], x4 = ns_prb['winner coop'],
                                y1 = st['median coop'], y2 = ns['median coop'], 
                                y3 = prb['median coop'], y4 = ns_prb['median coop'],
                                title='',
                                filename='/home/nightwing/rsc/Annual-Report/img/median.pdf')
# Out:
# /home/nightwing/anaconda3/envs/axlml/lib/python3.5/site-packages/matplotlib/cbook.py:136: MatplotlibDeprecationWarning: The set_color_cycle attribute was deprecated in version 1.5. Use set_prop_cycle instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# Note for when we come back to this
# ----------------------------------
#
# **Up to now:**
#
# We have decided that looking at each tournament type individually is correct way to indentify what was going on in our tournaments. Afterwards, for each of the types we are performing the same analysis.
#
# - The highest & lowest cooperators joint plots are allowing us to see if your enviroment you would perform better when you are being cooperative or not. Furthermore, the joint plots of the $C_{W}$ and $C_{L}$ are giving us a better idea of the performance of the winner. The mean and the median show us for what $C$ our results stand. For example, our standar tournaments had a $\bar{C}$ of 0.5, noise 0.5, probends 0.8.
#
# - The $r-$ distribution allows us to see several of the above things together. How fast the curve is decreasing us showing how less cooperative you have to be in your enviroment.
#
# - Standar tournaments have shown that, being 0.8 $\times C^{*}$ can most of the times win you first place, in noise tournaments you would prefer to be less cooperative but not a complete defector and for probabilistic ending tournament you wanna be in a defecting mood.
#
# - For a player being in a probabilistic tournament or a noisy probabilistic tournament shows to have not a significant different effect.
#
# - We have to look more on the $r-$ distribution and discuss if we are missing any information
#
# - Plotting the points with size based on the tournament size does not seem to be much of a help, because of the big number of points.
#
# - I have not yet use the standar deviation of $C_{r}$
#
# **What to look forward:**
#
# - Instead of size based on the tournament size use color?
#
# - Make use of all the columns we are keeping information
#
# - We wil be given the stable states. Looking forward we have now a general idea of how our tournament types looked and we have a cheat sheet for how cooperative you would want to be. The stable states could give us a bit more information on that.
#
# - write a better interpetation for the $r-$ distribution.
#
# - look at intervals for both winner and looser. for example you out performed 50% of the population.
